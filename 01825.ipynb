# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka222007maity-dot/Regression-Analysis/blob/main/01825.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#bad fit model
import matplotlib.pyplot as plt
from scipy import stats
x=[20,25,26,25,30,34,40,40,40,80]
y=[21,28,27,26,33,36,31,35,41,95]
slope,intercept,r,p,std_err = stats.linregress(x,y)
def myfunc(x):
  return slope * x+intercept
mymodel = list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show()

# %%
#b1
slope
# Out:
# np.float64(1.196796338672769)

# %%
# b0
intercept
# Out:
# np.float64(-5.784668192219684)
